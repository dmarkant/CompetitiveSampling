# %%
# %load_ext autoreload
# %autoreload 2
from mypy.datautil import download_data_from_mysqldb
import json
import pandas as pd
import numpy as np
from sqlalchemy import *
import urllib2

# %%
dburl = "mysql://lab:fishneversink@gureckislab.org/mt_experiments"
tablename = "battleship_infounc_2"
datacolumn = "datastring"
df = download_data_from_mysqldb(dburl, tablename)
df = df[(df['codeversion']=='32.0')]

# %%
DATA = {}

# %%
#for uid in df['uniqueid'].values:
for uid in ['A19PATBI3SQNU0:3S06PH7KSR5QGCATYF5EQBRROP21DI']:
    if uid not in DATA and uid.count('debug')==0:
        url = 'http://cog-grpexp.appspot.com/data?uniqueId=%s' % uid
        try:
            ret = json.loads(urllib2.urlopen(url).read())
            data = json.loads(ret['data'])    
            DATA[uid] = [line['data'] for line in data]
            print 'loaded data for uid=%s' % uid
        except:
            print 'failed to load data for uid=%s' % uid

# %%
def finished(uid):
    if uid in DATA and len(filter(lambda line: len(line) >0 and line[0]=='finishing', DATA[uid])) > 0:
        return True
    else:
        return False

# %%
SUBJ = filter(lambda uid: finished(uid), df['uniqueid'].values)
print len(SUBJ)
# Out:
# 137

# %%
with open('/Users/markant/data/CompetitiveSampling/rttb-v0/rttb-v0-KEY.txt', 'w') as f:
    for sid in SUBJ:
        f.write('%s\n' % sid)

# %%
100 + np.sum([line[5] for line in filter(lambda d: len(d) > 3 and d[3]=='received_id', DATA['A3NF9B2NLCLZWT:33NF62TLXJ35PZW7GLX7YOI32ESKJ9'])])
# Out:
# 141.19999999999999

# %%
for uid in df['uniqueid'].values:
    if uid not in DATA:
        print 'no data for uid %s' % uid
    else:
        bonusline = filter(lambda d: len(d) == 4 and d[2]=='final_bonus', DATA[uid])
        if bonusline != []:
            bonus = bonusline[0][3]
        else:
            bonus = None
        print uid, bonus
# Out:
# A6WK319U256SM:3LQ8PUHQFLTISYBTSI9A9VNBXHCHI1 None
# A5EU1AQJNC7F2:3300DTYQT2IJPM8AFP6DXUHKWB1EQL 0.802
# A24MK3QPZ1V1L8:3WR9XG3T63CRR262UKLUOHOYEWF477 None
# no data for uid A1QUNP6IYOQMZ5:3HQUKB7LNFFIW309M0RP9JMWX4XHH8
# A25BDZJ7E8I0PG:3U5NZHP4LR3A9KYX5DZUISONJV7HPD 1.704
# A3KNO82DZ519HG:3M23Y66PO28RPNU81BCKG648X1XS62 2.212
# A2KHV2D09JAWPC:3ZQIG0FLQEH5BUQIMOUTPNNSK7KWVC 1.586
# AFSJI5O9NK3YM:3VP0C6EFSGXORSH3HEGY4X525CFM6K None
# A3BOZ602TN5WKP:3ZOTGHDK5ICHET0C17YEX6QZI1ROSN 0.628
# A213OUMF0EHT0T:3OUYGIZWR7ZZYKS175S9C0P6XE4P0I None
# A198WMOSQ05A0B:31QTRG6Q2TEWVFOMFD3I4SJQ9RKPYK 1.358
# A1BQCRF5Q76YFY:3HQUKB7LNFFIW309M0RP9JMWX4XHH8 0.718
# A39M1U0GJ1YWBD:3L4PIM1GQTHH7S41S5779NJ5A97YRK 2.376
# AZCV8JQ2NEFN8:3JBT3HLQF83W05YRBZ51IZSSFLOPZB None
# A115UFR6VA6OM1:3ND9UOO81K32FPEO8KSN2EPQT9IWLT None
# A90JBLDKW71DX:35GMH2SV3EIG4AVU0CE98PMKHAJEOD 2.178
# A27O2IILV3S5YS:3OLQQLKKNSQ23Z4XKZM40T5YIG8JEY 0.828
# A36470UBRH28GO:37C0GNLMHF4LNYBQ4LHVL7I8WYP6DO None
# ...
